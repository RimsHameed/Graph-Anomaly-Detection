# %% [markdown]
# #Graph Anomaly Prediction
#
# ---
# On Yelp Reviews Dataset and Elliptic dataset

# %% [markdown]
# ### Python Imports
# All relevant project libraries and utilities for the notebook are installed and imported here.

# %%
# !pip install spektral

# %%
# !pip install --ignore-installed --upgrade tensorflow

# %%
import os
import numpy as np
import scipy
import pickle
import math
import tensorflow as tf
from tensorflow import keras
from numpy import polynomial
from scipy.special import comb
import scipy.sparse as ss
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from typing import Optional
from tensorflow.keras import backend as KB
from tensorflow.experimental import Optional as OptTensor
from tensorflow.python.ops.numpy_ops import np_config

# %%
# from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.layers import Dropout, Input, Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %% [markdown]
# Spektral is a Python Library which is used for Graph Deep Learning based on Keras and TensorFlow. We have used this as an alternative to PyG Library.

# %%
import spektral as spktrl
from spektral.data import SingleLoader
from spektral.data import Dataset, Graph
from spektral.data.dataset import Dataset
from spektral.layers import MessagePassing
from spektral.layers import ops
from spektral.layers.convolutional.conv import Conv
from spektral.utils import normalized_laplacian, rescale_laplacian, laplacian, degree_matrix

# %%
from spektral.data.loaders import SingleLoader
from spektral.datasets.citation import Citation
from spektral.layers import ChebConv
from spektral.transforms import LayerPreprocess
from spektral.layers import GATConv

# %%
np_config.enable_numpy_behavior()

# %% [markdown]
# ### I. Data Importation

# %% [markdown]
# 1. Upload datasets to Drive and mount Drive
# 2. Unzip the datasets
# 3. Uncomment graph if testing this model on respective Elliptic dataset or Yelp dataset
# 4. Give path to the dataset

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
# !unzip gdrive/My\ Drive/ellipticFraud.zip

# %%
# !unzip gdrive/My\ Drive/yelpFraud.zip

# %%
# graph=pickle.load(open("/content/ellipticFraud.dat","rb"))

# %%
graph = pickle.load(open("/content/yelpFraud.dat", "rb"))

# %%
# Graph converted to spektral data object for processing in keras and tensor flow, 
# Its a graph container. 
# label is either anomolous or normal. 
class MyDataset(Dataset):

   def __init__(self, **kwargs):
      
        self.mask_tr = self.mask_te = self.mask_va = None
        self.num_nodes= self.num_features=None
        super().__init__(**kwargs)
   def read(self):
        g=graph  
        x = g.x
        a = g.a

        y = g.y.reshape(-1,1)
        anomaly = (g.y == 1)
        normal = (g.y == 0)
        label = (anomaly, normal)
        
        y=np.stack((normal, anomaly))
        y=y*1
        y=np.transpose(y)
        self.num_nodes= a.shape[0]
        self.num_features= x.shape[1]
        
        self.mask_tr = 1*g.train_mask
        self.mask_te = 1*g.test_mask
        self.mask_va = 1*g.val_mask

        return [Graph(x=x, a=a, y=y)]

# %%
dataset= MyDataset()
dataset[0]
# Out:
# Graph(n_nodes=46564, n_node_features=93, n_edge_features=None, n_labels=2)

# %%
# for processing on single graph, single data loader is used. 
#It internally converts sparse arrays and numpy arrays to keras Tensor. 

loader=SingleLoader(dataset)
inputs= loader.load()
inputs
# Out:
# <RepeatDataset element_spec=((TensorSpec(shape=(46564, 93), dtype=tf.float32, name=None), SparseTensorSpec(TensorShape([46564, 46564]), tf.float32)), TensorSpec(shape=(46564, 2), dtype=tf.int64, name=None))>

# %%
#We converted the binary masks to sample weights so that we can compute the
# average loss over the nodes (following original implementation by
# Kipf & Welling)

def mask_to_weights(mask):
    return mask / np.count_nonzero(mask)

weights_tr, weights_va, weights_te = (
    mask_to_weights(mask)
    for mask in (dataset.mask_tr, dataset.mask_va, dataset.mask_te)
)

# %% [markdown]
# ### II. Bernstein Convolution
# Bernstein polynomial makes a filter
#
# Call(): The messages are gathered from the neighbouring nodes. The number of neighbours depends on  the degree of polynomial. If degree is 'K', the messages are gathered from 'K' hop neighbours.
#
# Preprocess():
# A function preprocess is used to preprocess the input adjacency matrix using laplacian functions.
#
# get_bern_coeff():
# The filters are paramterized using bernstien polynomial co-efficients, the values range  between 0-1.

# %%
class BernConv(Conv):

    def __init__(
        self,
        channels,
        K=1,
        activation=None,
        use_bias=True,
        kernel_initializer="glorot_uniform",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        activity_regularizer=None,
        kernel_constraint=None,
        bias_constraint=None,
        **kwargs
    ):
        super().__init__(
            activation=activation,
            use_bias=use_bias,
            kernel_initializer=kernel_initializer,
            bias_initializer=bias_initializer,
            kernel_regularizer=kernel_regularizer,
            bias_regularizer=bias_regularizer,
            activity_regularizer=activity_regularizer,
            kernel_constraint=kernel_constraint,
            bias_constraint=bias_constraint,
            **kwargs
        )
        self.channels = channels
        self.K = K

        # initializer = tf.keras.initializers.RandomUniform(minval=0., maxval=1.)
        # self.wazn = (initializer(shape=(K+1, 1)))
        # # self.mask= tf.keras.backend.variable(self.wazn, trainable=True)
        # self.mask= tf.keras.backend.variable(self.wazn)

    def build(self, input_shape):
        assert len(input_shape) >= 2
        input_dim = input_shape[0][-1]
        
        # learnable weight matrix, Parameters are learned for high pass and low pass filters
        self.kernel = self.add_weight( 
            shape=(self.K, input_dim, self.channels),
            initializer=self.kernel_initializer,
            name="kernel",
            regularizer=self.kernel_regularizer,
            constraint=self.kernel_constraint,
        )
        if self.use_bias:
            self.bias = self.add_weight(
                shape=(self.channels,),
                initializer=self.bias_initializer,
                name="bias",
                regularizer=self.bias_regularizer,
                constraint=self.bias_constraint,
            )
        self.built = True

    def call(self, inputs, mask=None):

        # takes adjacency matrix and feature vector as input, 
        # adjacency matrix is preprocessed to laplacian and normalized laplacian   
        x, a = inputs  
        
        # messages are calculated 
        Bx_0 = ops.modal_dot(a, x)  
        Bx = [Bx_0]
        Bx_next = Bx_0
        out = tf.keras.backend.zeros_like(x)
        for i in range(self.K):
            bx_next = ops.modal_dot(a, Bx_next)
            Bx_next = KB.dot(Bx_next, self.kernel[i])
            Bx.append(Bx_next)    # depending on degree of polynomial, messages are gathered. 
        bern_coeff =  BernConv.get_bern_coeff(self.K)

        # the filters are paramterized using bernstien polynomial co-efficients, ranging between 0-1
        for k in range(0, self.K + 1):
            coeff = bern_coeff[k]
            basis = Bx[0] * coeff[0]
            for i in range(1, self.K + 1):
                basis += Bx[i] * coeff[i]
            out += basis
        return out


    @property
    def config(self):
        return {"channels": self.channels, "K": self.K}

    # part of conv layer, used to preprocess the input adjacency matrix depending on the use case
    @staticmethod
    def preprocess(a):
        a = normalized_laplacian(a)
        a = rescale_laplacian(a)
        return a

    # used to calculate bern co-efficients
    @staticmethod
    def get_bern_coeff(degree):

        def Bernstein(de, i):
            #coefficients = [0, ] * i + [math.comb(de, i)]
            coefficients = [0, ] * i + [comb(de, i)]
            
            first_term = polynomial.polynomial.Polynomial(coefficients)
            second_term = polynomial.polynomial.Polynomial([1, -1]) ** (de - i)
            return first_term * second_term

        out = []

        for i in range(degree + 1):
            out.append(Bernstein(degree, i).coef)

        return out

# %% [markdown]
# ### III. Train Model
#
# Model Parameters

# %%
# paramters for the network 

channels = 64  # Number of channels in the first layer
K = 5  # Max degree of the Bernstien polynomials
dropout = 0.3  # Dropout rate for the features
l2_reg = 2.5e-4  # L2 regularization rate
learning_rate = 5e-4  # Learning rate
epochs = 2000  # Number of training epochs
patience = 200  # Patience for early stopping
a_dtype = dataset[0].a.dtype  

N = dataset.n_nodes  # Number of nodes in the graph
F = dataset.n_node_features  # Original size of node features
n_out = dataset.n_labels  # Number of classes

# %%
# lambda function used to conduct operations between two keras layers. 
def custom_layer(inputs):
  a, b =inputs
  res=a[:, 0, :] * b[:, 0]
  for i in range(1, 2): # range is number of filters , here we are using 2 filters
      res += a[:, i, :] * b[:, i]
  return res

# %% [markdown]
# Model Definition

# %%
x_in = Input(shape=(F,)) # F is the dimenion of features , in case of yelp its 32
a_in = Input((N,), sparse=True, dtype=a_dtype) # N is the number of nodes // custom input to genrate layers of Model 


den1=Dense(channels, activation="relu")(x_in) # linear transformation from x_in to channels with relu activation . 
den2=Dense(channels)(den1) # another linear transformation with same input and output channels. 


# Two separate filters, one as high pass filter, other as low pass filter. Parameters are learned by the model 
conv1=BernConv(channels, k =5)
conv2=BernConv(channels, k=5)

# conv1=ChebConv(channels, k=5)
# conv2=ChebConv(channels, k=5)
h_list = []

h1 = conv1([den2, a_in])
h_list.append(h1)

h2 =conv2([den2, a_in])
h_list.append(h2)
# Filters are stacked together. 
h_filters = keras.backend.stack(h_list, axis=1)

print(h_filters)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# KerasTensor(type_spec=TensorSpec(shape=(None, 2, 64), dtype=tf.float32, name=None), name='tf.stack/stack:0', description="created by layer 'tf.stack'")

# %%
#Node Level Attention. where h_filters_proj and x_proj indicate weight matricies transformation of the filters and input feature vectors,  transformed linearly. 

h_filters_proj = Dense(channels, activation="tanh")(h_filters)
x_proj=Dense(channels, activation="tanh") (den2)
x_proj = tf.keras.backend.expand_dims(x_proj,axis=-1)


score_logit = tf.keras.backend.batch_dot(h_filters_proj, x_proj)
softmax =tf.keras.layers.Softmax(axis=1)

score = softmax(score_logit)

lmbda = tf.keras.layers.Lambda(custom_layer)
res=lmbda([h_filters , score])

# after calculating the score dropout is used with rate 0.3
do1= Dropout(rate=0.1)(res)
den3=Dense(n_out, activation="softmax")(do1)

# %% [markdown]
# Model Building

# %%
from tensorflow.keras.metrics import AUC
from sklearn.metrics import average_precision_score

model = Model(inputs=[x_in, a_in], outputs=den3)
optimizer = Adam(lr=learning_rate)

def pr_auc(y_true, y_pred):
    return tf.py_function(average_precision_score, (y_true, y_pred), tf.float64)
    
model.compile(
    optimizer=optimizer,
    loss=CategoricalCrossentropy(reduction="sum"),  # To compute mean
    weighted_metrics=["accuracy"],
    # metrics=[roc_auc,pr_auc]
    metrics=[AUC(name='ROC_auc'),pr_auc]) # to compute auc-roc and pr score. 

model.summary()
# Out:
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 93)]         0           []
#
#  dense (Dense)                  (None, 64)           6016        ['input_1[0][0]']
#
#  dense_1 (Dense)                (None, 64)           4160        ['dense[0][0]']
#
#  input_2 (InputLayer)           [(None, 46564)]      0           []
#
#  bern_conv (BernConv)           (None, 64)           4160        ['dense_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  bern_conv_1 (BernConv)         (None, 64)           4160        ['dense_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  tf.stack (TFOpLambda)          (None, 2, 64)        0           ['bern_conv[0][0]',
#                                                                   'bern_conv_1[0][0]']
#
#  dense_12 (Dense)               (None, 64)           4160        ['dense_1[0][0]']
#
#  dense_11 (Dense)               (None, 2, 64)        4160        ['tf.stack[0][0]']
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 64, 1)        0           ['dense_12[0][0]']
#
#  tf.linalg.matmul_3 (TFOpLambda  (None, 2, 1)        0           ['dense_11[0][0]',
#  )                                                                'tf.expand_dims_3[0][0]']
#
#  softmax_3 (Softmax)            (None, 2, 1)         0           ['tf.linalg.matmul_3[0][0]']
#
#  lambda_3 (Lambda)              (None, 64)           0           ['tf.stack[0][0]',
#                                                                   'softmax_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 64)           0           ['lambda_3[0][0]']
#
#  dense_13 (Dense)               (None, 2)            130         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 26,946
# Trainable params: 26,946
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Model Training

# %%
# Loader is used to feed data into the model
loader_tr = SingleLoader(dataset, sample_weights=weights_tr) 
loader_va = SingleLoader(dataset, sample_weights=weights_va)

# %%
model.fit(
    loader_tr.load(),
    steps_per_epoch=loader_tr.steps_per_epoch,
    validation_data=loader_va.load(),
    validation_steps=loader_va.steps_per_epoch,
    epochs=epochs,
    callbacks=[EarlyStopping(patience=patience, restore_best_weights=True)],
)
# Out:
# Epoch 1/2000
# WARNING:tensorflow:Gradients do not exist for variables ['bern_conv_2/bias:0', 'bern_conv_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bern_conv_2/bias:0', 'bern_conv_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bern_conv_2/bias:0', 'bern_conv_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['bern_conv_2/bias:0', 'bern_conv_3/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 1/1 [==============================] - 5s 5s/step - loss: 10.9717 - ROC_auc: 0.7221 - pr_auc: 0.5048 - accuracy: 0.7018 - val_loss: 14.1528 - val_ROC_auc: 0.8555 - val_pr_auc: 0.5090 - val_accuracy: 0.8547
# Epoch 2/2000
# 1/1 [==============================] - 0s 251ms/step - loss: 14.9158 - ROC_auc: 0.8465 - pr_auc: 0.5061 - accuracy: 0.8415 - val_loss: 10.9002 - val_ROC_auc: 0.8557 - val_pr_auc: 0.5102 - val_accuracy: 0.8547
# Epoch 3/2000
# 1/1 [==============================] - 0s 243ms/step - loss: 12.0195 - ROC_auc: 0.8333 - pr_auc: 0.5071 - accuracy: 0.8245 - val_loss: 5.4820 - val_ROC_auc: 0.8562 - val_pr_auc: 0.5121 - val_accuracy: 0.8512
# Epoch 4/2000
# 1/1 [==============================] - 0s 292ms/step - loss: 9.8465 - ROC_auc: 0.7509 - pr_auc: 0.5019 - accuracy: 0.7323 - val_loss: 1.9767 - val_ROC_auc: 0.8461 - val_pr_auc: 0.5150 - val_accuracy: 0.8114
# Epoch 5/2000
# 1/1 [==============================] - 0s 231ms/step - loss: 12.0863 - ROC_auc: 0.6210 - pr_auc: 0.5045 - accuracy: 0.6063 - val_loss: 3.3961 - val_ROC_auc: 0.8573 - val_pr_auc: 0.5128 - val_accuracy: 0.8436
# Epoch 6/2000
# 1/1 [==============================] - 0s 277ms/step - loss: 10.0075 - ROC_auc: 0.6917 - pr_auc: 0.5038 - accuracy: 0.6711 - val_loss: 6.3008 - val_ROC_auc: 0.8559 - val_pr_auc: 0.5121 - val_accuracy: 0.8525
# Epoch 7/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 8.9897 - ROC_auc: 0.7885 - pr_auc: 0.5077 - accuracy: 0.7719 - val_loss: 8.3917 - val_ROC_auc: 0.8561 - val_pr_auc: 0.5110 - val_accuracy: 0.8544
# Epoch 8/2000
# 1/1 [==============================] - 0s 210ms/step - loss: 9.8699 - ROC_auc: 0.8240 - pr_auc: 0.5057 - accuracy: 0.8096 - val_loss: 8.9540 - val_ROC_auc: 0.8562 - val_pr_auc: 0.5109 - val_accuracy: 0.8544
# Epoch 9/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 9.9871 - ROC_auc: 0.8327 - pr_auc: 0.5067 - accuracy: 0.8208 - val_loss: 8.1603 - val_ROC_auc: 0.8562 - val_pr_auc: 0.5111 - val_accuracy: 0.8542
# Epoch 10/2000
# 1/1 [==============================] - 0s 266ms/step - loss: 9.0977 - ROC_auc: 0.8301 - pr_auc: 0.5082 - accuracy: 0.8179 - val_loss: 6.3707 - val_ROC_auc: 0.8559 - val_pr_auc: 0.5122 - val_accuracy: 0.8527
# Epoch 11/2000
# 1/1 [==============================] - 0s 210ms/step - loss: 8.2208 - ROC_auc: 0.8070 - pr_auc: 0.5061 - accuracy: 0.7897 - val_loss: 4.1619 - val_ROC_auc: 0.8569 - val_pr_auc: 0.5125 - val_accuracy: 0.8486
# Epoch 12/2000
# 1/1 [==============================] - 0s 267ms/step - loss: 7.7205 - ROC_auc: 0.7515 - pr_auc: 0.5048 - accuracy: 0.7303 - val_loss: 2.5343 - val_ROC_auc: 0.8558 - val_pr_auc: 0.5143 - val_accuracy: 0.8327
# Epoch 13/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 8.0951 - ROC_auc: 0.6834 - pr_auc: 0.5027 - accuracy: 0.6628 - val_loss: 2.3903 - val_ROC_auc: 0.8551 - val_pr_auc: 0.5149 - val_accuracy: 0.8312
# Epoch 14/2000
# 1/1 [==============================] - 0s 207ms/step - loss: 7.8136 - ROC_auc: 0.6843 - pr_auc: 0.5067 - accuracy: 0.6596 - val_loss: 3.4403 - val_ROC_auc: 0.8577 - val_pr_auc: 0.5128 - val_accuracy: 0.8442
# Epoch 15/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 7.0126 - ROC_auc: 0.7445 - pr_auc: 0.5055 - accuracy: 0.7205 - val_loss: 4.7847 - val_ROC_auc: 0.8567 - val_pr_auc: 0.5128 - val_accuracy: 0.8501
# Epoch 16/2000
# 1/1 [==============================] - 0s 209ms/step - loss: 6.6267 - ROC_auc: 0.7975 - pr_auc: 0.5068 - accuracy: 0.7745 - val_loss: 5.6085 - val_ROC_auc: 0.8564 - val_pr_auc: 0.5121 - val_accuracy: 0.8520
# Epoch 17/2000
# 1/1 [==============================] - 0s 201ms/step - loss: 6.7459 - ROC_auc: 0.8209 - pr_auc: 0.5084 - accuracy: 0.8024 - val_loss: 5.6453 - val_ROC_auc: 0.8563 - val_pr_auc: 0.5121 - val_accuracy: 0.8523
# Epoch 18/2000
# 1/1 [==============================] - 0s 203ms/step - loss: 6.7962 - ROC_auc: 0.8233 - pr_auc: 0.5071 - accuracy: 0.8058 - val_loss: 4.9410 - val_ROC_auc: 0.8566 - val_pr_auc: 0.5127 - val_accuracy: 0.8510
# Epoch 19/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 6.1295 - ROC_auc: 0.8173 - pr_auc: 0.5086 - accuracy: 0.7965 - val_loss: 3.7117 - val_ROC_auc: 0.8575 - val_pr_auc: 0.5125 - val_accuracy: 0.8464
# Epoch 20/2000
# 1/1 [==============================] - 0s 265ms/step - loss: 5.6666 - ROC_auc: 0.7853 - pr_auc: 0.5077 - accuracy: 0.7594 - val_loss: 2.5125 - val_ROC_auc: 0.8571 - val_pr_auc: 0.5145 - val_accuracy: 0.8336
# Epoch 21/2000
# 1/1 [==============================] - 0s 268ms/step - loss: 5.7736 - ROC_auc: 0.7272 - pr_auc: 0.5051 - accuracy: 0.6968 - val_loss: 2.0798 - val_ROC_auc: 0.8547 - val_pr_auc: 0.5159 - val_accuracy: 0.8251
# Epoch 22/2000
# 1/1 [==============================] - 0s 205ms/step - loss: 5.6748 - ROC_auc: 0.7067 - pr_auc: 0.5074 - accuracy: 0.6773 - val_loss: 2.5147 - val_ROC_auc: 0.8571 - val_pr_auc: 0.5145 - val_accuracy: 0.8340
# Epoch 23/2000
# 1/1 [==============================] - 0s 269ms/step - loss: 5.1770 - ROC_auc: 0.7453 - pr_auc: 0.5065 - accuracy: 0.7174 - val_loss: 3.3029 - val_ROC_auc: 0.8578 - val_pr_auc: 0.5128 - val_accuracy: 0.8446
# Epoch 24/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 4.9786 - ROC_auc: 0.7900 - pr_auc: 0.5052 - accuracy: 0.7608 - val_loss: 3.8487 - val_ROC_auc: 0.8574 - val_pr_auc: 0.5126 - val_accuracy: 0.8481
# Epoch 25/2000
# 1/1 [==============================] - 0s 208ms/step - loss: 4.9907 - ROC_auc: 0.8138 - pr_auc: 0.5082 - accuracy: 0.7895 - val_loss: 3.8341 - val_ROC_auc: 0.8574 - val_pr_auc: 0.5126 - val_accuracy: 0.8481
# Epoch 26/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 4.7904 - ROC_auc: 0.8198 - pr_auc: 0.5101 - accuracy: 0.7951 - val_loss: 3.2516 - val_ROC_auc: 0.8577 - val_pr_auc: 0.5127 - val_accuracy: 0.8444
# Epoch 27/2000
# 1/1 [==============================] - 0s 207ms/step - loss: 4.4879 - ROC_auc: 0.8031 - pr_auc: 0.5073 - accuracy: 0.7734 - val_loss: 2.4030 - val_ROC_auc: 0.8575 - val_pr_auc: 0.5149 - val_accuracy: 0.8338
# Epoch 28/2000
# 1/1 [==============================] - 0s 236ms/step - loss: 4.2456 - ROC_auc: 0.7671 - pr_auc: 0.5078 - accuracy: 0.7324 - val_loss: 1.8030 - val_ROC_auc: 0.8532 - val_pr_auc: 0.5162 - val_accuracy: 0.8192
# Epoch 29/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 4.2248 - ROC_auc: 0.7269 - pr_auc: 0.5080 - accuracy: 0.6913 - val_loss: 1.8448 - val_ROC_auc: 0.8537 - val_pr_auc: 0.5162 - val_accuracy: 0.8203
# Epoch 30/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 4.0960 - ROC_auc: 0.7364 - pr_auc: 0.5065 - accuracy: 0.7009 - val_loss: 2.3787 - val_ROC_auc: 0.8576 - val_pr_auc: 0.5146 - val_accuracy: 0.8336
# Epoch 31/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 3.8069 - ROC_auc: 0.7829 - pr_auc: 0.5072 - accuracy: 0.7482 - val_loss: 2.8485 - val_ROC_auc: 0.8580 - val_pr_auc: 0.5124 - val_accuracy: 0.8392
# Epoch 32/2000
# 1/1 [==============================] - 0s 210ms/step - loss: 3.7798 - ROC_auc: 0.8112 - pr_auc: 0.5099 - accuracy: 0.7798 - val_loss: 2.8586 - val_ROC_auc: 0.8580 - val_pr_auc: 0.5123 - val_accuracy: 0.8392
# Epoch 33/2000
# 1/1 [==============================] - 0s 278ms/step - loss: 3.6432 - ROC_auc: 0.8161 - pr_auc: 0.5110 - accuracy: 0.7834 - val_loss: 2.4057 - val_ROC_auc: 0.8579 - val_pr_auc: 0.5136 - val_accuracy: 0.8342
# Epoch 34/2000
# 1/1 [==============================] - 0s 284ms/step - loss: 3.4917 - ROC_auc: 0.7983 - pr_auc: 0.5073 - accuracy: 0.7614 - val_loss: 1.7897 - val_ROC_auc: 0.8550 - val_pr_auc: 0.5164 - val_accuracy: 0.8211
# Epoch 35/2000
# 1/1 [==============================] - 0s 277ms/step - loss: 3.3603 - ROC_auc: 0.7572 - pr_auc: 0.5088 - accuracy: 0.7187 - val_loss: 1.5475 - val_ROC_auc: 0.8529 - val_pr_auc: 0.5173 - val_accuracy: 0.8164
# Epoch 36/2000
# 1/1 [==============================] - 0s 268ms/step - loss: 3.3806 - ROC_auc: 0.7365 - pr_auc: 0.5066 - accuracy: 0.6941 - val_loss: 1.8417 - val_ROC_auc: 0.8558 - val_pr_auc: 0.5162 - val_accuracy: 0.8235
# Epoch 37/2000
# 1/1 [==============================] - 0s 207ms/step - loss: 3.1051 - ROC_auc: 0.7744 - pr_auc: 0.5090 - accuracy: 0.7335 - val_loss: 2.2332 - val_ROC_auc: 0.8573 - val_pr_auc: 0.5142 - val_accuracy: 0.8320
# Epoch 38/2000
# 1/1 [==============================] - 0s 211ms/step - loss: 3.0888 - ROC_auc: 0.8075 - pr_auc: 0.5089 - accuracy: 0.7647 - val_loss: 2.3094 - val_ROC_auc: 0.8572 - val_pr_auc: 0.5131 - val_accuracy: 0.8329
# Epoch 39/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 3.0617 - ROC_auc: 0.8151 - pr_auc: 0.5086 - accuracy: 0.7780 - val_loss: 1.9379 - val_ROC_auc: 0.8570 - val_pr_auc: 0.5161 - val_accuracy: 0.8264
# Epoch 40/2000
# 1/1 [==============================] - 0s 214ms/step - loss: 2.8684 - ROC_auc: 0.7946 - pr_auc: 0.5103 - accuracy: 0.7541 - val_loss: 1.4889 - val_ROC_auc: 0.8524 - val_pr_auc: 0.5171 - val_accuracy: 0.8161
# Epoch 41/2000
# 1/1 [==============================] - 0s 287ms/step - loss: 2.8786 - ROC_auc: 0.7522 - pr_auc: 0.5063 - accuracy: 0.7088 - val_loss: 1.4574 - val_ROC_auc: 0.8520 - val_pr_auc: 0.5171 - val_accuracy: 0.8161
# Epoch 42/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 2.7351 - ROC_auc: 0.7550 - pr_auc: 0.5088 - accuracy: 0.7125 - val_loss: 1.7662 - val_ROC_auc: 0.8563 - val_pr_auc: 0.5162 - val_accuracy: 0.8240
# Epoch 43/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 2.6242 - ROC_auc: 0.7949 - pr_auc: 0.5102 - accuracy: 0.7486 - val_loss: 1.9727 - val_ROC_auc: 0.8577 - val_pr_auc: 0.5157 - val_accuracy: 0.8281
# Epoch 44/2000
# 1/1 [==============================] - 0s 210ms/step - loss: 2.6209 - ROC_auc: 0.8158 - pr_auc: 0.5105 - accuracy: 0.7716 - val_loss: 1.7653 - val_ROC_auc: 0.8566 - val_pr_auc: 0.5162 - val_accuracy: 0.8246
# Epoch 45/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 2.5140 - ROC_auc: 0.7998 - pr_auc: 0.5080 - accuracy: 0.7553 - val_loss: 1.3952 - val_ROC_auc: 0.8525 - val_pr_auc: 0.5171 - val_accuracy: 0.8172
# Epoch 46/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 2.5057 - ROC_auc: 0.7628 - pr_auc: 0.5058 - accuracy: 0.7155 - val_loss: 1.3187 - val_ROC_auc: 0.8512 - val_pr_auc: 0.5171 - val_accuracy: 0.8157
# Epoch 47/2000
# 1/1 [==============================] - 0s 274ms/step - loss: 2.3670 - ROC_auc: 0.7615 - pr_auc: 0.5107 - accuracy: 0.7115 - val_loss: 1.5427 - val_ROC_auc: 0.8553 - val_pr_auc: 0.5167 - val_accuracy: 0.8209
# Epoch 48/2000
# 1/1 [==============================] - 0s 269ms/step - loss: 2.3124 - ROC_auc: 0.7955 - pr_auc: 0.5096 - accuracy: 0.7461 - val_loss: 1.6691 - val_ROC_auc: 0.8567 - val_pr_auc: 0.5164 - val_accuracy: 0.8251
# Epoch 49/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 2.3144 - ROC_auc: 0.8098 - pr_auc: 0.5090 - accuracy: 0.7641 - val_loss: 1.5220 - val_ROC_auc: 0.8560 - val_pr_auc: 0.5167 - val_accuracy: 0.8225
# Epoch 50/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 2.2390 - ROC_auc: 0.8004 - pr_auc: 0.5090 - accuracy: 0.7502 - val_loss: 1.2530 - val_ROC_auc: 0.8518 - val_pr_auc: 0.5171 - val_accuracy: 0.8166
# Epoch 51/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 2.1742 - ROC_auc: 0.7689 - pr_auc: 0.5090 - accuracy: 0.7183 - val_loss: 1.2453 - val_ROC_auc: 0.8523 - val_pr_auc: 0.5172 - val_accuracy: 0.8170
# Epoch 52/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 2.1029 - ROC_auc: 0.7745 - pr_auc: 0.5098 - accuracy: 0.7214 - val_loss: 1.4388 - val_ROC_auc: 0.8563 - val_pr_auc: 0.5172 - val_accuracy: 0.8233
# Epoch 53/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 2.0655 - ROC_auc: 0.8032 - pr_auc: 0.5093 - accuracy: 0.7557 - val_loss: 1.4609 - val_ROC_auc: 0.8571 - val_pr_auc: 0.5174 - val_accuracy: 0.8244
# Epoch 54/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 2.0379 - ROC_auc: 0.8091 - pr_auc: 0.5107 - accuracy: 0.7610 - val_loss: 1.2597 - val_ROC_auc: 0.8544 - val_pr_auc: 0.5177 - val_accuracy: 0.8192
# Epoch 55/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 1.9621 - ROC_auc: 0.7864 - pr_auc: 0.5111 - accuracy: 0.7337 - val_loss: 1.1583 - val_ROC_auc: 0.8535 - val_pr_auc: 0.5179 - val_accuracy: 0.8164
# Epoch 56/2000
# 1/1 [==============================] - 0s 278ms/step - loss: 1.9360 - ROC_auc: 0.7757 - pr_auc: 0.5107 - accuracy: 0.7227 - val_loss: 1.2517 - val_ROC_auc: 0.8555 - val_pr_auc: 0.5180 - val_accuracy: 0.8211
# Epoch 57/2000
# 1/1 [==============================] - 0s 211ms/step - loss: 1.9063 - ROC_auc: 0.7970 - pr_auc: 0.5114 - accuracy: 0.7426 - val_loss: 1.3349 - val_ROC_auc: 0.8573 - val_pr_auc: 0.5182 - val_accuracy: 0.8248
# Epoch 58/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 1.8877 - ROC_auc: 0.8092 - pr_auc: 0.5110 - accuracy: 0.7587 - val_loss: 1.2118 - val_ROC_auc: 0.8563 - val_pr_auc: 0.5185 - val_accuracy: 0.8216
# Epoch 59/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 1.8033 - ROC_auc: 0.7971 - pr_auc: 0.5111 - accuracy: 0.7470 - val_loss: 1.0868 - val_ROC_auc: 0.8547 - val_pr_auc: 0.5188 - val_accuracy: 0.8192
# Epoch 60/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 1.7809 - ROC_auc: 0.7803 - pr_auc: 0.5118 - accuracy: 0.7247 - val_loss: 1.1567 - val_ROC_auc: 0.8569 - val_pr_auc: 0.5191 - val_accuracy: 0.8225
# Epoch 61/2000
# 1/1 [==============================] - 0s 209ms/step - loss: 1.7696 - ROC_auc: 0.7961 - pr_auc: 0.5101 - accuracy: 0.7427 - val_loss: 1.2311 - val_ROC_auc: 0.8584 - val_pr_auc: 0.5192 - val_accuracy: 0.8275
# Epoch 62/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.7135 - ROC_auc: 0.8127 - pr_auc: 0.5131 - accuracy: 0.7618 - val_loss: 1.0917 - val_ROC_auc: 0.8572 - val_pr_auc: 0.5197 - val_accuracy: 0.8235
# Epoch 63/2000
# 1/1 [==============================] - 0s 284ms/step - loss: 1.6976 - ROC_auc: 0.7945 - pr_auc: 0.5100 - accuracy: 0.7434 - val_loss: 0.9907 - val_ROC_auc: 0.8570 - val_pr_auc: 0.5201 - val_accuracy: 0.8198
# Epoch 64/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 1.6721 - ROC_auc: 0.7799 - pr_auc: 0.5106 - accuracy: 0.7230 - val_loss: 1.1338 - val_ROC_auc: 0.8594 - val_pr_auc: 0.5204 - val_accuracy: 0.8288
# Epoch 65/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 1.6274 - ROC_auc: 0.8095 - pr_auc: 0.5133 - accuracy: 0.7590 - val_loss: 1.1385 - val_ROC_auc: 0.8601 - val_pr_auc: 0.5208 - val_accuracy: 0.8312
# Epoch 66/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 1.5966 - ROC_auc: 0.8156 - pr_auc: 0.5132 - accuracy: 0.7631 - val_loss: 0.9444 - val_ROC_auc: 0.8588 - val_pr_auc: 0.5214 - val_accuracy: 0.8218
# Epoch 67/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 1.5843 - ROC_auc: 0.7855 - pr_auc: 0.5139 - accuracy: 0.7290 - val_loss: 1.0052 - val_ROC_auc: 0.8605 - val_pr_auc: 0.5216 - val_accuracy: 0.8283
# Epoch 68/2000
# 1/1 [==============================] - 0s 269ms/step - loss: 1.5326 - ROC_auc: 0.8024 - pr_auc: 0.5149 - accuracy: 0.7489 - val_loss: 1.0695 - val_ROC_auc: 0.8609 - val_pr_auc: 0.5220 - val_accuracy: 0.8314
# Epoch 69/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 1.5134 - ROC_auc: 0.8149 - pr_auc: 0.5139 - accuracy: 0.7630 - val_loss: 0.9666 - val_ROC_auc: 0.8612 - val_pr_auc: 0.5226 - val_accuracy: 0.8288
# Epoch 70/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 1.4743 - ROC_auc: 0.7993 - pr_auc: 0.5135 - accuracy: 0.7462 - val_loss: 0.9347 - val_ROC_auc: 0.8619 - val_pr_auc: 0.5231 - val_accuracy: 0.8264
# Epoch 71/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 1.4882 - ROC_auc: 0.7972 - pr_auc: 0.5137 - accuracy: 0.7423 - val_loss: 1.0295 - val_ROC_auc: 0.8620 - val_pr_auc: 0.5231 - val_accuracy: 0.8329
# Epoch 72/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.4630 - ROC_auc: 0.8163 - pr_auc: 0.5119 - accuracy: 0.7658 - val_loss: 0.9160 - val_ROC_auc: 0.8626 - val_pr_auc: 0.5238 - val_accuracy: 0.8272
# Epoch 73/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 1.4011 - ROC_auc: 0.8033 - pr_auc: 0.5165 - accuracy: 0.7509 - val_loss: 0.9171 - val_ROC_auc: 0.8631 - val_pr_auc: 0.5240 - val_accuracy: 0.8281
# Epoch 74/2000
# 1/1 [==============================] - 0s 268ms/step - loss: 1.4112 - ROC_auc: 0.8044 - pr_auc: 0.5142 - accuracy: 0.7495 - val_loss: 0.9827 - val_ROC_auc: 0.8633 - val_pr_auc: 0.5240 - val_accuracy: 0.8346
# Epoch 75/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 1.3649 - ROC_auc: 0.8185 - pr_auc: 0.5148 - accuracy: 0.7695 - val_loss: 0.8675 - val_ROC_auc: 0.8633 - val_pr_auc: 0.5249 - val_accuracy: 0.8272
# Epoch 76/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 1.3616 - ROC_auc: 0.7986 - pr_auc: 0.5145 - accuracy: 0.7426 - val_loss: 0.9274 - val_ROC_auc: 0.8642 - val_pr_auc: 0.5247 - val_accuracy: 0.8316
# Epoch 77/2000
# 1/1 [==============================] - 0s 267ms/step - loss: 1.3167 - ROC_auc: 0.8171 - pr_auc: 0.5169 - accuracy: 0.7634 - val_loss: 0.8763 - val_ROC_auc: 0.8642 - val_pr_auc: 0.5252 - val_accuracy: 0.8303
# Epoch 78/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 1.2963 - ROC_auc: 0.8081 - pr_auc: 0.5147 - accuracy: 0.7553 - val_loss: 0.8539 - val_ROC_auc: 0.8641 - val_pr_auc: 0.5256 - val_accuracy: 0.8283
# Epoch 79/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.2881 - ROC_auc: 0.8057 - pr_auc: 0.5156 - accuracy: 0.7536 - val_loss: 0.9178 - val_ROC_auc: 0.8650 - val_pr_auc: 0.5251 - val_accuracy: 0.8342
# Epoch 80/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.2755 - ROC_auc: 0.8213 - pr_auc: 0.5157 - accuracy: 0.7711 - val_loss: 0.7940 - val_ROC_auc: 0.8627 - val_pr_auc: 0.5261 - val_accuracy: 0.8220
# Epoch 81/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 1.2652 - ROC_auc: 0.7940 - pr_auc: 0.5161 - accuracy: 0.7368 - val_loss: 0.9364 - val_ROC_auc: 0.8650 - val_pr_auc: 0.5251 - val_accuracy: 0.8366
# Epoch 82/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 1.2379 - ROC_auc: 0.8309 - pr_auc: 0.5195 - accuracy: 0.7791 - val_loss: 0.8009 - val_ROC_auc: 0.8634 - val_pr_auc: 0.5262 - val_accuracy: 0.8251
# Epoch 83/2000
# 1/1 [==============================] - 0s 214ms/step - loss: 1.2103 - ROC_auc: 0.8040 - pr_auc: 0.5163 - accuracy: 0.7467 - val_loss: 0.8110 - val_ROC_auc: 0.8642 - val_pr_auc: 0.5261 - val_accuracy: 0.8279
# Epoch 84/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 1.2086 - ROC_auc: 0.8110 - pr_auc: 0.5179 - accuracy: 0.7547 - val_loss: 0.8821 - val_ROC_auc: 0.8655 - val_pr_auc: 0.5257 - val_accuracy: 0.8344
# Epoch 85/2000
# 1/1 [==============================] - 0s 283ms/step - loss: 1.1863 - ROC_auc: 0.8275 - pr_auc: 0.5172 - accuracy: 0.7781 - val_loss: 0.7399 - val_ROC_auc: 0.8607 - val_pr_auc: 0.5271 - val_accuracy: 0.8153
# Epoch 86/2000
# 1/1 [==============================] - 0s 214ms/step - loss: 1.1923 - ROC_auc: 0.7884 - pr_auc: 0.5146 - accuracy: 0.7342 - val_loss: 0.9059 - val_ROC_auc: 0.8657 - val_pr_auc: 0.5255 - val_accuracy: 0.8364
# Epoch 87/2000
# 1/1 [==============================] - 0s 279ms/step - loss: 1.1724 - ROC_auc: 0.8347 - pr_auc: 0.5178 - accuracy: 0.7849 - val_loss: 0.7389 - val_ROC_auc: 0.8615 - val_pr_auc: 0.5272 - val_accuracy: 0.8172
# Epoch 88/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 1.1593 - ROC_auc: 0.7948 - pr_auc: 0.5152 - accuracy: 0.7398 - val_loss: 0.8108 - val_ROC_auc: 0.8650 - val_pr_auc: 0.5263 - val_accuracy: 0.8305
# Epoch 89/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 1.1112 - ROC_auc: 0.8205 - pr_auc: 0.5185 - accuracy: 0.7670 - val_loss: 0.7888 - val_ROC_auc: 0.8647 - val_pr_auc: 0.5267 - val_accuracy: 0.8268
# Epoch 90/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 1.1004 - ROC_auc: 0.8162 - pr_auc: 0.5181 - accuracy: 0.7616 - val_loss: 0.7533 - val_ROC_auc: 0.8636 - val_pr_auc: 0.5272 - val_accuracy: 0.8216
# Epoch 91/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 1.1236 - ROC_auc: 0.8066 - pr_auc: 0.5156 - accuracy: 0.7496 - val_loss: 0.8050 - val_ROC_auc: 0.8654 - val_pr_auc: 0.5265 - val_accuracy: 0.8316
# Epoch 92/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 1.0886 - ROC_auc: 0.8264 - pr_auc: 0.5180 - accuracy: 0.7713 - val_loss: 0.7023 - val_ROC_auc: 0.8601 - val_pr_auc: 0.5280 - val_accuracy: 0.8105
# Epoch 93/2000
# 1/1 [==============================] - 0s 220ms/step - loss: 1.0913 - ROC_auc: 0.7918 - pr_auc: 0.5162 - accuracy: 0.7327 - val_loss: 0.8894 - val_ROC_auc: 0.8663 - val_pr_auc: 0.5260 - val_accuracy: 0.8362
# Epoch 94/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.1125 - ROC_auc: 0.8405 - pr_auc: 0.5178 - accuracy: 0.7944 - val_loss: 0.6806 - val_ROC_auc: 0.8576 - val_pr_auc: 0.5289 - val_accuracy: 0.8048
# Epoch 95/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 1.0916 - ROC_auc: 0.7843 - pr_auc: 0.5160 - accuracy: 0.7268 - val_loss: 0.8230 - val_ROC_auc: 0.8665 - val_pr_auc: 0.5267 - val_accuracy: 0.8342
# Epoch 96/2000
# 1/1 [==============================] - 0s 211ms/step - loss: 1.0699 - ROC_auc: 0.8342 - pr_auc: 0.5186 - accuracy: 0.7845 - val_loss: 0.7062 - val_ROC_auc: 0.8631 - val_pr_auc: 0.5289 - val_accuracy: 0.8185
# Epoch 97/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 1.0348 - ROC_auc: 0.8077 - pr_auc: 0.5186 - accuracy: 0.7487 - val_loss: 0.7113 - val_ROC_auc: 0.8639 - val_pr_auc: 0.5290 - val_accuracy: 0.8207
# Epoch 98/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 1.0303 - ROC_auc: 0.8108 - pr_auc: 0.5179 - accuracy: 0.7536 - val_loss: 0.7942 - val_ROC_auc: 0.8669 - val_pr_auc: 0.5277 - val_accuracy: 0.8340
# Epoch 99/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 1.0350 - ROC_auc: 0.8347 - pr_auc: 0.5199 - accuracy: 0.7832 - val_loss: 0.6620 - val_ROC_auc: 0.8576 - val_pr_auc: 0.5310 - val_accuracy: 0.8053
# Epoch 100/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.0187 - ROC_auc: 0.7880 - pr_auc: 0.5182 - accuracy: 0.7287 - val_loss: 0.8399 - val_ROC_auc: 0.8678 - val_pr_auc: 0.5273 - val_accuracy: 0.8359
# Epoch 101/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 1.0508 - ROC_auc: 0.8436 - pr_auc: 0.5187 - accuracy: 0.7974 - val_loss: 0.6561 - val_ROC_auc: 0.8577 - val_pr_auc: 0.5319 - val_accuracy: 0.8042
# Epoch 102/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 1.0131 - ROC_auc: 0.7899 - pr_auc: 0.5179 - accuracy: 0.7318 - val_loss: 0.7711 - val_ROC_auc: 0.8676 - val_pr_auc: 0.5290 - val_accuracy: 0.8342
# Epoch 103/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.0095 - ROC_auc: 0.8345 - pr_auc: 0.5182 - accuracy: 0.7855 - val_loss: 0.6753 - val_ROC_auc: 0.8637 - val_pr_auc: 0.5320 - val_accuracy: 0.8190
# Epoch 104/2000
# 1/1 [==============================] - 0s 285ms/step - loss: 0.9790 - ROC_auc: 0.8096 - pr_auc: 0.5185 - accuracy: 0.7492 - val_loss: 0.6870 - val_ROC_auc: 0.8654 - val_pr_auc: 0.5319 - val_accuracy: 0.8231
# Epoch 105/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 0.9731 - ROC_auc: 0.8178 - pr_auc: 0.5199 - accuracy: 0.7598 - val_loss: 0.7343 - val_ROC_auc: 0.8680 - val_pr_auc: 0.5305 - val_accuracy: 0.8314
# Epoch 106/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 0.9821 - ROC_auc: 0.8334 - pr_auc: 0.5189 - accuracy: 0.7824 - val_loss: 0.6379 - val_ROC_auc: 0.8547 - val_pr_auc: 0.5338 - val_accuracy: 0.8009
# Epoch 107/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.9817 - ROC_auc: 0.7852 - pr_auc: 0.5192 - accuracy: 0.7237 - val_loss: 0.8675 - val_ROC_auc: 0.8686 - val_pr_auc: 0.5280 - val_accuracy: 0.8405
# Epoch 108/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 1.0162 - ROC_auc: 0.8537 - pr_auc: 0.5235 - accuracy: 0.8113 - val_loss: 0.6320 - val_ROC_auc: 0.8536 - val_pr_auc: 0.5344 - val_accuracy: 0.7990
# Epoch 109/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 0.9667 - ROC_auc: 0.7835 - pr_auc: 0.5214 - accuracy: 0.7264 - val_loss: 0.7540 - val_ROC_auc: 0.8689 - val_pr_auc: 0.5304 - val_accuracy: 0.8362
# Epoch 110/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 0.9588 - ROC_auc: 0.8422 - pr_auc: 0.5212 - accuracy: 0.7941 - val_loss: 0.6385 - val_ROC_auc: 0.8604 - val_pr_auc: 0.5345 - val_accuracy: 0.8111
# Epoch 111/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 0.9402 - ROC_auc: 0.8028 - pr_auc: 0.5208 - accuracy: 0.7436 - val_loss: 0.7148 - val_ROC_auc: 0.8687 - val_pr_auc: 0.5318 - val_accuracy: 0.8329
# Epoch 112/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 0.9242 - ROC_auc: 0.8378 - pr_auc: 0.5226 - accuracy: 0.7856 - val_loss: 0.6374 - val_ROC_auc: 0.8618 - val_pr_auc: 0.5346 - val_accuracy: 0.8118
# Epoch 113/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 0.9258 - ROC_auc: 0.8050 - pr_auc: 0.5194 - accuracy: 0.7485 - val_loss: 0.7163 - val_ROC_auc: 0.8691 - val_pr_auc: 0.5317 - val_accuracy: 0.8338
# Epoch 114/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.9185 - ROC_auc: 0.8390 - pr_auc: 0.5237 - accuracy: 0.7883 - val_loss: 0.6230 - val_ROC_auc: 0.8578 - val_pr_auc: 0.5351 - val_accuracy: 0.8046
# Epoch 115/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 0.9275 - ROC_auc: 0.7952 - pr_auc: 0.5206 - accuracy: 0.7367 - val_loss: 0.7786 - val_ROC_auc: 0.8697 - val_pr_auc: 0.5302 - val_accuracy: 0.8399
# Epoch 116/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 0.9530 - ROC_auc: 0.8481 - pr_auc: 0.5216 - accuracy: 0.8040 - val_loss: 0.6137 - val_ROC_auc: 0.8503 - val_pr_auc: 0.5359 - val_accuracy: 0.7933
# Epoch 117/2000
# 1/1 [==============================] - 0s 211ms/step - loss: 0.9309 - ROC_auc: 0.7792 - pr_auc: 0.5191 - accuracy: 0.7212 - val_loss: 0.8212 - val_ROC_auc: 0.8695 - val_pr_auc: 0.5294 - val_accuracy: 0.8425
# Epoch 118/2000
# 1/1 [==============================] - 0s 280ms/step - loss: 0.9707 - ROC_auc: 0.8537 - pr_auc: 0.5231 - accuracy: 0.8135 - val_loss: 0.6132 - val_ROC_auc: 0.8568 - val_pr_auc: 0.5359 - val_accuracy: 0.8029
# Epoch 119/2000
# 1/1 [==============================] - 0s 211ms/step - loss: 0.9020 - ROC_auc: 0.7929 - pr_auc: 0.5193 - accuracy: 0.7355 - val_loss: 0.6838 - val_ROC_auc: 0.8692 - val_pr_auc: 0.5331 - val_accuracy: 0.8327
# Epoch 120/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 0.8868 - ROC_auc: 0.8366 - pr_auc: 0.5238 - accuracy: 0.7856 - val_loss: 0.6328 - val_ROC_auc: 0.8654 - val_pr_auc: 0.5352 - val_accuracy: 0.8203
# Epoch 121/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 0.8795 - ROC_auc: 0.8182 - pr_auc: 0.5209 - accuracy: 0.7622 - val_loss: 0.6359 - val_ROC_auc: 0.8664 - val_pr_auc: 0.5352 - val_accuracy: 0.8220
# Epoch 122/2000
# 1/1 [==============================] - 0s 274ms/step - loss: 0.8820 - ROC_auc: 0.8197 - pr_auc: 0.5191 - accuracy: 0.7639 - val_loss: 0.6703 - val_ROC_auc: 0.8692 - val_pr_auc: 0.5339 - val_accuracy: 0.8314
# Epoch 123/2000
# 1/1 [==============================] - 0s 284ms/step - loss: 0.8675 - ROC_auc: 0.8367 - pr_auc: 0.5232 - accuracy: 0.7854 - val_loss: 0.6042 - val_ROC_auc: 0.8577 - val_pr_auc: 0.5375 - val_accuracy: 0.8035
# Epoch 124/2000
# 1/1 [==============================] - 0s 283ms/step - loss: 0.8753 - ROC_auc: 0.7967 - pr_auc: 0.5230 - accuracy: 0.7379 - val_loss: 0.8068 - val_ROC_auc: 0.8700 - val_pr_auc: 0.5305 - val_accuracy: 0.8438
# Epoch 125/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 0.9420 - ROC_auc: 0.8554 - pr_auc: 0.5230 - accuracy: 0.8186 - val_loss: 0.5997 - val_ROC_auc: 0.8451 - val_pr_auc: 0.5388 - val_accuracy: 0.7861
# Epoch 126/2000
# 1/1 [==============================] - 0s 225ms/step - loss: 0.8907 - ROC_auc: 0.7750 - pr_auc: 0.5221 - accuracy: 0.7155 - val_loss: 0.8137 - val_ROC_auc: 0.8700 - val_pr_auc: 0.5306 - val_accuracy: 0.8440
# Epoch 127/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 0.9430 - ROC_auc: 0.8581 - pr_auc: 0.5247 - accuracy: 0.8203 - val_loss: 0.5985 - val_ROC_auc: 0.8595 - val_pr_auc: 0.5386 - val_accuracy: 0.8068
# Epoch 128/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 0.8578 - ROC_auc: 0.8013 - pr_auc: 0.5225 - accuracy: 0.7445 - val_loss: 0.6244 - val_ROC_auc: 0.8674 - val_pr_auc: 0.5367 - val_accuracy: 0.8246
# Epoch 129/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 0.8493 - ROC_auc: 0.8243 - pr_auc: 0.5234 - accuracy: 0.7689 - val_loss: 0.6898 - val_ROC_auc: 0.8708 - val_pr_auc: 0.5338 - val_accuracy: 0.8379
# Epoch 130/2000
# 1/1 [==============================] - 0s 232ms/step - loss: 0.8758 - ROC_auc: 0.8440 - pr_auc: 0.5219 - accuracy: 0.7984 - val_loss: 0.5944 - val_ROC_auc: 0.8411 - val_pr_auc: 0.5394 - val_accuracy: 0.7829
# Epoch 131/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.8914 - ROC_auc: 0.7669 - pr_auc: 0.5225 - accuracy: 0.7096 - val_loss: 0.9616 - val_ROC_auc: 0.8675 - val_pr_auc: 0.5297 - val_accuracy: 0.8505
# Epoch 132/2000
# 1/1 [==============================] - 0s 245ms/step - loss: 1.0377 - ROC_auc: 0.8630 - pr_auc: 0.5246 - accuracy: 0.8355 - val_loss: 0.6374 - val_ROC_auc: 0.8694 - val_pr_auc: 0.5361 - val_accuracy: 0.8305
# Epoch 133/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 0.8396 - ROC_auc: 0.8351 - pr_auc: 0.5235 - accuracy: 0.7846 - val_loss: 0.9764 - val_ROC_auc: 0.5740 - val_pr_auc: 0.5306 - val_accuracy: 0.5522
# Epoch 134/2000
# 1/1 [==============================] - 0s 210ms/step - loss: 1.3984 - ROC_auc: 0.5428 - pr_auc: 0.5175 - accuracy: 0.5311 - val_loss: 2.2650 - val_ROC_auc: 0.8623 - val_pr_auc: 0.5196 - val_accuracy: 0.8544
# Epoch 135/2000
# 1/1 [==============================] - 0s 265ms/step - loss: 2.3339 - ROC_auc: 0.8615 - pr_auc: 0.5186 - accuracy: 0.8537 - val_loss: 3.2403 - val_ROC_auc: 0.8594 - val_pr_auc: 0.5174 - val_accuracy: 0.8547
# Epoch 136/2000
# 1/1 [==============================] - 0s 209ms/step - loss: 3.3164 - ROC_auc: 0.8591 - pr_auc: 0.5174 - accuracy: 0.8543 - val_loss: 3.0777 - val_ROC_auc: 0.8596 - val_pr_auc: 0.5177 - val_accuracy: 0.8547
# Epoch 137/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 3.1438 - ROC_auc: 0.8595 - pr_auc: 0.5168 - accuracy: 0.8544 - val_loss: 1.9376 - val_ROC_auc: 0.8635 - val_pr_auc: 0.5209 - val_accuracy: 0.8547
# Epoch 138/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.9880 - ROC_auc: 0.8627 - pr_auc: 0.5199 - accuracy: 0.8529 - val_loss: 1.0027 - val_ROC_auc: 0.5515 - val_pr_auc: 0.5303 - val_accuracy: 0.5352
# Epoch 139/2000
# 1/1 [==============================] - 0s 285ms/step - loss: 1.4043 - ROC_auc: 0.5299 - pr_auc: 0.5201 - accuracy: 0.5215 - val_loss: 0.7536 - val_ROC_auc: 0.8711 - val_pr_auc: 0.5329 - val_accuracy: 0.8453
# Epoch 140/2000
# 1/1 [==============================] - 0s 274ms/step - loss: 0.8872 - ROC_auc: 0.8549 - pr_auc: 0.5228 - accuracy: 0.8149 - val_loss: 0.9126 - val_ROC_auc: 0.8689 - val_pr_auc: 0.5301 - val_accuracy: 0.8499
# Epoch 141/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 1.0023 - ROC_auc: 0.8646 - pr_auc: 0.5270 - accuracy: 0.8342 - val_loss: 0.5817 - val_ROC_auc: 0.8641 - val_pr_auc: 0.5416 - val_accuracy: 0.8164
# Epoch 142/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 0.8173 - ROC_auc: 0.8129 - pr_auc: 0.5256 - accuracy: 0.7565 - val_loss: 0.6401 - val_ROC_auc: 0.7855 - val_pr_auc: 0.5370 - val_accuracy: 0.7204
# Epoch 143/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 0.9897 - ROC_auc: 0.6998 - pr_auc: 0.5194 - accuracy: 0.6518 - val_loss: 1.0966 - val_ROC_auc: 0.8650 - val_pr_auc: 0.5280 - val_accuracy: 0.8529
# Epoch 144/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 1.1610 - ROC_auc: 0.8654 - pr_auc: 0.5255 - accuracy: 0.8442 - val_loss: 1.1813 - val_ROC_auc: 0.8646 - val_pr_auc: 0.5270 - val_accuracy: 0.8536
# Epoch 145/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 1.2497 - ROC_auc: 0.8644 - pr_auc: 0.5229 - accuracy: 0.8446 - val_loss: 0.6245 - val_ROC_auc: 0.8705 - val_pr_auc: 0.5388 - val_accuracy: 0.8346
# Epoch 146/2000
# 1/1 [==============================] - 0s 230ms/step - loss: 0.8094 - ROC_auc: 0.8396 - pr_auc: 0.5245 - accuracy: 0.7910 - val_loss: 1.6427 - val_ROC_auc: 0.3114 - val_pr_auc: 0.5244 - val_accuracy: 0.3507
# Epoch 147/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 1.9977 - ROC_auc: 0.3667 - pr_auc: 0.5141 - accuracy: 0.3998 - val_loss: 1.9298 - val_ROC_auc: 0.8632 - val_pr_auc: 0.5205 - val_accuracy: 0.8547
# Epoch 148/2000
# 1/1 [==============================] - 0s 272ms/step - loss: 1.9789 - ROC_auc: 0.8630 - pr_auc: 0.5204 - accuracy: 0.8528 - val_loss: 3.1468 - val_ROC_auc: 0.8595 - val_pr_auc: 0.5172 - val_accuracy: 0.8547
# Epoch 149/2000
# 1/1 [==============================] - 0s 207ms/step - loss: 3.2119 - ROC_auc: 0.8596 - pr_auc: 0.5171 - accuracy: 0.8545 - val_loss: 3.5367 - val_ROC_auc: 0.8588 - val_pr_auc: 0.5171 - val_accuracy: 0.8547
# Epoch 150/2000
# 1/1 [==============================] - 0s 207ms/step - loss: 3.6078 - ROC_auc: 0.8586 - pr_auc: 0.5164 - accuracy: 0.8544 - val_loss: 3.1941 - val_ROC_auc: 0.8594 - val_pr_auc: 0.5171 - val_accuracy: 0.8547
# Epoch 151/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 3.2602 - ROC_auc: 0.8593 - pr_auc: 0.5169 - accuracy: 0.8543 - val_loss: 2.2144 - val_ROC_auc: 0.8621 - val_pr_auc: 0.5193 - val_accuracy: 0.8547
# Epoch 152/2000
# 1/1 [==============================] - 0s 282ms/step - loss: 2.2768 - ROC_auc: 0.8616 - pr_auc: 0.5181 - accuracy: 0.8532 - val_loss: 0.7409 - val_ROC_auc: 0.8712 - val_pr_auc: 0.5330 - val_accuracy: 0.8462
# Epoch 153/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 0.8714 - ROC_auc: 0.8553 - pr_auc: 0.5234 - accuracy: 0.8184 - val_loss: 6.3586 - val_ROC_auc: 0.1475 - val_pr_auc: 0.5030 - val_accuracy: 0.1752
# Epoch 154/2000
# 1/1 [==============================] - 0s 212ms/step - loss: 6.3807 - ROC_auc: 0.1545 - pr_auc: 0.5005 - accuracy: 0.1952 - val_loss: 0.9123 - val_ROC_auc: 0.8689 - val_pr_auc: 0.5295 - val_accuracy: 0.8512
# Epoch 155/2000
# 1/1 [==============================] - 0s 269ms/step - loss: 1.0015 - ROC_auc: 0.8636 - pr_auc: 0.5250 - accuracy: 0.8364 - val_loss: 2.1845 - val_ROC_auc: 0.8622 - val_pr_auc: 0.5191 - val_accuracy: 0.8547
# Epoch 156/2000
# 1/1 [==============================] - 0s 214ms/step - loss: 2.2271 - ROC_auc: 0.8618 - pr_auc: 0.5200 - accuracy: 0.8537 - val_loss: 2.8231 - val_ROC_auc: 0.8600 - val_pr_auc: 0.5175 - val_accuracy: 0.8547
# Epoch 157/2000
# 1/1 [==============================] - 0s 274ms/step - loss: 2.8813 - ROC_auc: 0.8601 - pr_auc: 0.5177 - accuracy: 0.8541 - val_loss: 2.8748 - val_ROC_auc: 0.8600 - val_pr_auc: 0.5174 - val_accuracy: 0.8547
# Epoch 158/2000
# 1/1 [==============================] - 0s 208ms/step - loss: 2.9487 - ROC_auc: 0.8596 - pr_auc: 0.5170 - accuracy: 0.8541 - val_loss: 2.4102 - val_ROC_auc: 0.8612 - val_pr_auc: 0.5184 - val_accuracy: 0.8547
# Epoch 159/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 2.4738 - ROC_auc: 0.8611 - pr_auc: 0.5178 - accuracy: 0.8540 - val_loss: 1.5044 - val_ROC_auc: 0.8638 - val_pr_auc: 0.5246 - val_accuracy: 0.8549
# Epoch 160/2000
# 1/1 [==============================] - 0s 270ms/step - loss: 1.5668 - ROC_auc: 0.8641 - pr_auc: 0.5214 - accuracy: 0.8499 - val_loss: 0.5868 - val_ROC_auc: 0.8195 - val_pr_auc: 0.5390 - val_accuracy: 0.7491
# Epoch 161/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 0.9356 - ROC_auc: 0.7278 - pr_auc: 0.5208 - accuracy: 0.6740 - val_loss: 2.5263 - val_ROC_auc: 0.1996 - val_pr_auc: 0.5185 - val_accuracy: 0.2448
# Epoch 162/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 2.7704 - ROC_auc: 0.2617 - pr_auc: 0.5136 - accuracy: 0.3162 - val_loss: 1.2126 - val_ROC_auc: 0.8645 - val_pr_auc: 0.5263 - val_accuracy: 0.8538
# Epoch 163/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.2764 - ROC_auc: 0.8643 - pr_auc: 0.5234 - accuracy: 0.8461 - val_loss: 2.2262 - val_ROC_auc: 0.8617 - val_pr_auc: 0.5188 - val_accuracy: 0.8547
# Epoch 164/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 2.2930 - ROC_auc: 0.8616 - pr_auc: 0.5180 - accuracy: 0.8533 - val_loss: 2.7028 - val_ROC_auc: 0.8600 - val_pr_auc: 0.5175 - val_accuracy: 0.8547
# Epoch 165/2000
# 1/1 [==============================] - 0s 267ms/step - loss: 2.7610 - ROC_auc: 0.8601 - pr_auc: 0.5172 - accuracy: 0.8542 - val_loss: 2.6935 - val_ROC_auc: 0.8601 - val_pr_auc: 0.5176 - val_accuracy: 0.8547
# Epoch 166/2000
# 1/1 [==============================] - 0s 265ms/step - loss: 2.7629 - ROC_auc: 0.8605 - pr_auc: 0.5166 - accuracy: 0.8543 - val_loss: 2.2539 - val_ROC_auc: 0.8616 - val_pr_auc: 0.5187 - val_accuracy: 0.8547
# Epoch 167/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 2.3082 - ROC_auc: 0.8612 - pr_auc: 0.5182 - accuracy: 0.8538 - val_loss: 1.4438 - val_ROC_auc: 0.8640 - val_pr_auc: 0.5245 - val_accuracy: 0.8544
# Epoch 168/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 1.5002 - ROC_auc: 0.8635 - pr_auc: 0.5212 - accuracy: 0.8493 - val_loss: 0.5549 - val_ROC_auc: 0.8541 - val_pr_auc: 0.5417 - val_accuracy: 0.7957
# Epoch 169/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 0.8311 - ROC_auc: 0.7823 - pr_auc: 0.5219 - accuracy: 0.7264 - val_loss: 2.9638 - val_ROC_auc: 0.1782 - val_pr_auc: 0.5165 - val_accuracy: 0.2178
# Epoch 170/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 3.1501 - ROC_auc: 0.2253 - pr_auc: 0.5096 - accuracy: 0.2809 - val_loss: 0.8590 - val_ROC_auc: 0.8694 - val_pr_auc: 0.5298 - val_accuracy: 0.8497
# Epoch 171/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.9626 - ROC_auc: 0.8619 - pr_auc: 0.5240 - accuracy: 0.8297 - val_loss: 1.7203 - val_ROC_auc: 0.8635 - val_pr_auc: 0.5225 - val_accuracy: 0.8549
# Epoch 172/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 1.7723 - ROC_auc: 0.8638 - pr_auc: 0.5212 - accuracy: 0.8517 - val_loss: 2.1431 - val_ROC_auc: 0.8619 - val_pr_auc: 0.5190 - val_accuracy: 0.8547
# Epoch 173/2000
# 1/1 [==============================] - 0s 208ms/step - loss: 2.1988 - ROC_auc: 0.8618 - pr_auc: 0.5183 - accuracy: 0.8534 - val_loss: 2.1465 - val_ROC_auc: 0.8619 - val_pr_auc: 0.5190 - val_accuracy: 0.8547
# Epoch 174/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 2.2137 - ROC_auc: 0.8618 - pr_auc: 0.5181 - accuracy: 0.8534 - val_loss: 1.7780 - val_ROC_auc: 0.8633 - val_pr_auc: 0.5219 - val_accuracy: 0.8549
# Epoch 175/2000
# 1/1 [==============================] - 0s 280ms/step - loss: 1.8392 - ROC_auc: 0.8628 - pr_auc: 0.5194 - accuracy: 0.8519 - val_loss: 1.0961 - val_ROC_auc: 0.8650 - val_pr_auc: 0.5269 - val_accuracy: 0.8536
# Epoch 176/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 1.1802 - ROC_auc: 0.8644 - pr_auc: 0.5230 - accuracy: 0.8435 - val_loss: 0.6408 - val_ROC_auc: 0.7660 - val_pr_auc: 0.5362 - val_accuracy: 0.6967
# Epoch 177/2000
# 1/1 [==============================] - 0s 215ms/step - loss: 0.9741 - ROC_auc: 0.6834 - pr_auc: 0.5216 - accuracy: 0.6415 - val_loss: 1.4278 - val_ROC_auc: 0.3435 - val_pr_auc: 0.5254 - val_accuracy: 0.3877
# Epoch 178/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 1.7561 - ROC_auc: 0.3966 - pr_auc: 0.5158 - accuracy: 0.4262 - val_loss: 0.8635 - val_ROC_auc: 0.8690 - val_pr_auc: 0.5292 - val_accuracy: 0.8507
# Epoch 179/2000
# 1/1 [==============================] - 0s 271ms/step - loss: 0.9617 - ROC_auc: 0.8618 - pr_auc: 0.5227 - accuracy: 0.8331 - val_loss: 1.4761 - val_ROC_auc: 0.8637 - val_pr_auc: 0.5241 - val_accuracy: 0.8542
# Epoch 180/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 1.5274 - ROC_auc: 0.8647 - pr_auc: 0.5228 - accuracy: 0.8502 - val_loss: 1.7101 - val_ROC_auc: 0.8633 - val_pr_auc: 0.5221 - val_accuracy: 0.8549
# Epoch 181/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 1.7732 - ROC_auc: 0.8634 - pr_auc: 0.5210 - accuracy: 0.8524 - val_loss: 1.5826 - val_ROC_auc: 0.8636 - val_pr_auc: 0.5232 - val_accuracy: 0.8549
# Epoch 182/2000
# 1/1 [==============================] - 0s 226ms/step - loss: 1.6405 - ROC_auc: 0.8634 - pr_auc: 0.5215 - accuracy: 0.8517 - val_loss: 1.1426 - val_ROC_auc: 0.8648 - val_pr_auc: 0.5262 - val_accuracy: 0.8540
# Epoch 183/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 1.2098 - ROC_auc: 0.8646 - pr_auc: 0.5223 - accuracy: 0.8451 - val_loss: 0.5641 - val_ROC_auc: 0.8680 - val_pr_auc: 0.5433 - val_accuracy: 0.8294
# Epoch 184/2000
# 1/1 [==============================] - 0s 220ms/step - loss: 0.7786 - ROC_auc: 0.8212 - pr_auc: 0.5203 - accuracy: 0.7668 - val_loss: 1.5747 - val_ROC_auc: 0.2950 - val_pr_auc: 0.5242 - val_accuracy: 0.3440
# Epoch 185/2000
# 1/1 [==============================] - 0s 220ms/step - loss: 1.8780 - ROC_auc: 0.3605 - pr_auc: 0.5156 - accuracy: 0.4014 - val_loss: 0.6195 - val_ROC_auc: 0.8710 - val_pr_auc: 0.5392 - val_accuracy: 0.8438
# Epoch 186/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.7788 - ROC_auc: 0.8459 - pr_auc: 0.5243 - accuracy: 0.7976 - val_loss: 1.1026 - val_ROC_auc: 0.8651 - val_pr_auc: 0.5265 - val_accuracy: 0.8534
# Epoch 187/2000
# 1/1 [==============================] - 0s 213ms/step - loss: 1.1713 - ROC_auc: 0.8642 - pr_auc: 0.5244 - accuracy: 0.8449 - val_loss: 1.3065 - val_ROC_auc: 0.8645 - val_pr_auc: 0.5248 - val_accuracy: 0.8538
# Epoch 188/2000
# 1/1 [==============================] - 0s 222ms/step - loss: 1.3574 - ROC_auc: 0.8645 - pr_auc: 0.5248 - accuracy: 0.8491 - val_loss: 1.1916 - val_ROC_auc: 0.8645 - val_pr_auc: 0.5257 - val_accuracy: 0.8542
# Epoch 189/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 1.2484 - ROC_auc: 0.8651 - pr_auc: 0.5251 - accuracy: 0.8487 - val_loss: 0.8126 - val_ROC_auc: 0.8694 - val_pr_auc: 0.5293 - val_accuracy: 0.8499
# Epoch 190/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 0.9075 - ROC_auc: 0.8621 - pr_auc: 0.5250 - accuracy: 0.8336 - val_loss: 0.5823 - val_ROC_auc: 0.8068 - val_pr_auc: 0.5386 - val_accuracy: 0.7359
# Epoch 191/2000
# 1/1 [==============================] - 0s 216ms/step - loss: 0.8829 - ROC_auc: 0.7182 - pr_auc: 0.5208 - accuracy: 0.6651 - val_loss: 0.7998 - val_ROC_auc: 0.6316 - val_pr_auc: 0.5334 - val_accuracy: 0.5944
# Epoch 192/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 1.1460 - ROC_auc: 0.5799 - pr_auc: 0.5182 - accuracy: 0.5597 - val_loss: 0.6803 - val_ROC_auc: 0.8713 - val_pr_auc: 0.5330 - val_accuracy: 0.8455
# Epoch 193/2000
# 1/1 [==============================] - 0s 220ms/step - loss: 0.8030 - ROC_auc: 0.8563 - pr_auc: 0.5243 - accuracy: 0.8171 - val_loss: 1.0076 - val_ROC_auc: 0.8652 - val_pr_auc: 0.5271 - val_accuracy: 0.8531
# Epoch 194/2000
# 1/1 [==============================] - 0s 214ms/step - loss: 1.0717 - ROC_auc: 0.8643 - pr_auc: 0.5245 - accuracy: 0.8439 - val_loss: 1.0651 - val_ROC_auc: 0.8651 - val_pr_auc: 0.5266 - val_accuracy: 0.8536
# Epoch 195/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 1.1347 - ROC_auc: 0.8637 - pr_auc: 0.5223 - accuracy: 0.8450 - val_loss: 0.8527 - val_ROC_auc: 0.8683 - val_pr_auc: 0.5284 - val_accuracy: 0.8507
# Epoch 196/2000
# 1/1 [==============================] - 0s 228ms/step - loss: 0.9280 - ROC_auc: 0.8632 - pr_auc: 0.5241 - accuracy: 0.8361 - val_loss: 0.5420 - val_ROC_auc: 0.8662 - val_pr_auc: 0.5429 - val_accuracy: 0.8216
# Epoch 197/2000
# 1/1 [==============================] - 0s 279ms/step - loss: 0.7497 - ROC_auc: 0.8174 - pr_auc: 0.5241 - accuracy: 0.7595 - val_loss: 0.7889 - val_ROC_auc: 0.6352 - val_pr_auc: 0.5340 - val_accuracy: 0.5990
# Epoch 198/2000
# 1/1 [==============================] - 0s 221ms/step - loss: 1.1175 - ROC_auc: 0.5810 - pr_auc: 0.5193 - accuracy: 0.5599 - val_loss: 0.5620 - val_ROC_auc: 0.8697 - val_pr_auc: 0.5407 - val_accuracy: 0.8351
# Epoch 199/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.7373 - ROC_auc: 0.8344 - pr_auc: 0.5259 - accuracy: 0.7791 - val_loss: 0.8139 - val_ROC_auc: 0.8690 - val_pr_auc: 0.5291 - val_accuracy: 0.8501
# Epoch 200/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.9029 - ROC_auc: 0.8623 - pr_auc: 0.5222 - accuracy: 0.8329 - val_loss: 0.8878 - val_ROC_auc: 0.8672 - val_pr_auc: 0.5281 - val_accuracy: 0.8516
# Epoch 201/2000
# 1/1 [==============================] - 0s 224ms/step - loss: 0.9647 - ROC_auc: 0.8638 - pr_auc: 0.5237 - accuracy: 0.8400 - val_loss: 0.7325 - val_ROC_auc: 0.8706 - val_pr_auc: 0.5309 - val_accuracy: 0.8483
# Epoch 202/2000
# 1/1 [==============================] - 0s 276ms/step - loss: 0.8352 - ROC_auc: 0.8608 - pr_auc: 0.5233 - accuracy: 0.8264 - val_loss: 0.5300 - val_ROC_auc: 0.8622 - val_pr_auc: 0.5432 - val_accuracy: 0.8120
# Epoch 203/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.7519 - ROC_auc: 0.8042 - pr_auc: 0.5223 - accuracy: 0.7478 - val_loss: 0.6343 - val_ROC_auc: 0.7561 - val_pr_auc: 0.5376 - val_accuracy: 0.6843
# Epoch 204/2000
# 1/1 [==============================] - 0s 223ms/step - loss: 0.9368 - ROC_auc: 0.6696 - pr_auc: 0.5202 - accuracy: 0.6276 - val_loss: 0.5552 - val_ROC_auc: 0.8698 - val_pr_auc: 0.5404 - val_accuracy: 0.8329
# Epoch 205/2000
# 1/1 [==============================] - 0s 278ms/step - loss: 0.7270 - ROC_auc: 0.8341 - pr_auc: 0.5254 - accuracy: 0.7797 - val_loss: 0.7356 - val_ROC_auc: 0.8707 - val_pr_auc: 0.5309 - val_accuracy: 0.8486
# Epoch 206/2000
# 1/1 [==============================] - 0s 220ms/step - loss: 0.8350 - ROC_auc: 0.8606 - pr_auc: 0.5231 - accuracy: 0.8276 - val_loss: 0.7708 - val_ROC_auc: 0.8695 - val_pr_auc: 0.5302 - val_accuracy: 0.8492
# Epoch 207/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 0.8674 - ROC_auc: 0.8616 - pr_auc: 0.5233 - accuracy: 0.8304 - val_loss: 0.6315 - val_ROC_auc: 0.8717 - val_pr_auc: 0.5344 - val_accuracy: 0.8446
# Epoch 208/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.7575 - ROC_auc: 0.8537 - pr_auc: 0.5246 - accuracy: 0.8122 - val_loss: 0.5284 - val_ROC_auc: 0.8519 - val_pr_auc: 0.5430 - val_accuracy: 0.7942
# Epoch 209/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.7622 - ROC_auc: 0.7809 - pr_auc: 0.5228 - accuracy: 0.7219 - val_loss: 0.5506 - val_ROC_auc: 0.8280 - val_pr_auc: 0.5412 - val_accuracy: 0.7594
# Epoch 210/2000
# 1/1 [==============================] - 0s 218ms/step - loss: 0.8165 - ROC_auc: 0.7430 - pr_auc: 0.5228 - accuracy: 0.6845 - val_loss: 0.5734 - val_ROC_auc: 0.8714 - val_pr_auc: 0.5385 - val_accuracy: 0.8401
# Epoch 211/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 0.7279 - ROC_auc: 0.8423 - pr_auc: 0.5238 - accuracy: 0.7909 - val_loss: 0.6972 - val_ROC_auc: 0.8709 - val_pr_auc: 0.5324 - val_accuracy: 0.8488
# Epoch 212/2000
# 1/1 [==============================] - 0s 219ms/step - loss: 0.7849 - ROC_auc: 0.8605 - pr_auc: 0.5269 - accuracy: 0.8260 - val_loss: 0.6804 - val_ROC_auc: 0.8713 - val_pr_auc: 0.5330 - val_accuracy: 0.8483
# Epoch 213/2000
# ...
# Epoch 1930/2000
# 1/1 [==============================] - 0s 327ms/step - loss: 0.4206 - ROC_auc: 0.8769 - pr_auc: 0.5458 - accuracy: 0.8537 - val_loss: 0.4054 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1931/2000
# 1/1 [==============================] - 0s 296ms/step - loss: 0.4188 - ROC_auc: 0.8768 - pr_auc: 0.5475 - accuracy: 0.8539 - val_loss: 0.4060 - val_ROC_auc: 0.8844 - val_pr_auc: 0.5684 - val_accuracy: 0.8562
# Epoch 1932/2000
# 1/1 [==============================] - 0s 313ms/step - loss: 0.4198 - ROC_auc: 0.8763 - pr_auc: 0.5455 - accuracy: 0.8540 - val_loss: 0.4061 - val_ROC_auc: 0.8843 - val_pr_auc: 0.5684 - val_accuracy: 0.8562
# Epoch 1933/2000
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4200 - ROC_auc: 0.8770 - pr_auc: 0.5462 - accuracy: 0.8537 - val_loss: 0.4054 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1934/2000
# 1/1 [==============================] - 0s 320ms/step - loss: 0.4194 - ROC_auc: 0.8759 - pr_auc: 0.5448 - accuracy: 0.8532 - val_loss: 0.4075 - val_ROC_auc: 0.8839 - val_pr_auc: 0.5680 - val_accuracy: 0.8562
# Epoch 1935/2000
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4185 - ROC_auc: 0.8778 - pr_auc: 0.5487 - accuracy: 0.8547 - val_loss: 0.4054 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1936/2000
# 1/1 [==============================] - 0s 322ms/step - loss: 0.4190 - ROC_auc: 0.8766 - pr_auc: 0.5465 - accuracy: 0.8530 - val_loss: 0.4063 - val_ROC_auc: 0.8843 - val_pr_auc: 0.5684 - val_accuracy: 0.8562
# Epoch 1937/2000
# 1/1 [==============================] - 0s 332ms/step - loss: 0.4170 - ROC_auc: 0.8781 - pr_auc: 0.5487 - accuracy: 0.8541 - val_loss: 0.4058 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1938/2000
# 1/1 [==============================] - 0s 279ms/step - loss: 0.4186 - ROC_auc: 0.8767 - pr_auc: 0.5454 - accuracy: 0.8540 - val_loss: 0.4054 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1939/2000
# 1/1 [==============================] - 0s 328ms/step - loss: 0.4184 - ROC_auc: 0.8773 - pr_auc: 0.5474 - accuracy: 0.8539 - val_loss: 0.4064 - val_ROC_auc: 0.8843 - val_pr_auc: 0.5684 - val_accuracy: 0.8562
# Epoch 1940/2000
# 1/1 [==============================] - 0s 313ms/step - loss: 0.4183 - ROC_auc: 0.8780 - pr_auc: 0.5482 - accuracy: 0.8542 - val_loss: 0.4054 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1941/2000
# 1/1 [==============================] - 0s 239ms/step - loss: 0.4193 - ROC_auc: 0.8771 - pr_auc: 0.5474 - accuracy: 0.8542 - val_loss: 0.4057 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1942/2000
# 1/1 [==============================] - 0s 245ms/step - loss: 0.4204 - ROC_auc: 0.8766 - pr_auc: 0.5453 - accuracy: 0.8541 - val_loss: 0.4055 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1943/2000
# 1/1 [==============================] - 0s 306ms/step - loss: 0.4180 - ROC_auc: 0.8772 - pr_auc: 0.5478 - accuracy: 0.8541 - val_loss: 0.4055 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1944/2000
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4188 - ROC_auc: 0.8776 - pr_auc: 0.5474 - accuracy: 0.8539 - val_loss: 0.4060 - val_ROC_auc: 0.8844 - val_pr_auc: 0.5685 - val_accuracy: 0.8562
# Epoch 1945/2000
# 1/1 [==============================] - 0s 483ms/step - loss: 0.4190 - ROC_auc: 0.8769 - pr_auc: 0.5468 - accuracy: 0.8544 - val_loss: 0.4054 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1946/2000
# 1/1 [==============================] - 0s 332ms/step - loss: 0.4204 - ROC_auc: 0.8756 - pr_auc: 0.5435 - accuracy: 0.8536 - val_loss: 0.4058 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5686 - val_accuracy: 0.8562
# Epoch 1947/2000
# 1/1 [==============================] - 0s 303ms/step - loss: 0.4176 - ROC_auc: 0.8772 - pr_auc: 0.5484 - accuracy: 0.8549 - val_loss: 0.4054 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1948/2000
# 1/1 [==============================] - 0s 326ms/step - loss: 0.4165 - ROC_auc: 0.8784 - pr_auc: 0.5484 - accuracy: 0.8534 - val_loss: 0.4057 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1949/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.4188 - ROC_auc: 0.8769 - pr_auc: 0.5470 - accuracy: 0.8539 - val_loss: 0.4055 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1950/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.4193 - ROC_auc: 0.8772 - pr_auc: 0.5472 - accuracy: 0.8535 - val_loss: 0.4057 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1951/2000
# 1/1 [==============================] - 0s 318ms/step - loss: 0.4173 - ROC_auc: 0.8767 - pr_auc: 0.5468 - accuracy: 0.8546 - val_loss: 0.4053 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1952/2000
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4186 - ROC_auc: 0.8760 - pr_auc: 0.5452 - accuracy: 0.8545 - val_loss: 0.4065 - val_ROC_auc: 0.8842 - val_pr_auc: 0.5684 - val_accuracy: 0.8562
# Epoch 1953/2000
# 1/1 [==============================] - 0s 334ms/step - loss: 0.4187 - ROC_auc: 0.8773 - pr_auc: 0.5480 - accuracy: 0.8547 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1954/2000
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4175 - ROC_auc: 0.8773 - pr_auc: 0.5471 - accuracy: 0.8534 - val_loss: 0.4057 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1955/2000
# 1/1 [==============================] - 0s 311ms/step - loss: 0.4183 - ROC_auc: 0.8766 - pr_auc: 0.5471 - accuracy: 0.8544 - val_loss: 0.4058 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1956/2000
# 1/1 [==============================] - 0s 336ms/step - loss: 0.4207 - ROC_auc: 0.8760 - pr_auc: 0.5436 - accuracy: 0.8540 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1957/2000
# 1/1 [==============================] - 0s 286ms/step - loss: 0.4189 - ROC_auc: 0.8769 - pr_auc: 0.5474 - accuracy: 0.8538 - val_loss: 0.4063 - val_ROC_auc: 0.8843 - val_pr_auc: 0.5685 - val_accuracy: 0.8562
# Epoch 1958/2000
# 1/1 [==============================] - 0s 304ms/step - loss: 0.4166 - ROC_auc: 0.8782 - pr_auc: 0.5513 - accuracy: 0.8547 - val_loss: 0.4052 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1959/2000
# 1/1 [==============================] - 0s 332ms/step - loss: 0.4177 - ROC_auc: 0.8775 - pr_auc: 0.5491 - accuracy: 0.8542 - val_loss: 0.4056 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1960/2000
# 1/1 [==============================] - 0s 328ms/step - loss: 0.4183 - ROC_auc: 0.8774 - pr_auc: 0.5492 - accuracy: 0.8548 - val_loss: 0.4059 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1961/2000
# 1/1 [==============================] - 0s 345ms/step - loss: 0.4223 - ROC_auc: 0.8753 - pr_auc: 0.5435 - accuracy: 0.8539 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1962/2000
# 1/1 [==============================] - 0s 327ms/step - loss: 0.4197 - ROC_auc: 0.8763 - pr_auc: 0.5458 - accuracy: 0.8532 - val_loss: 0.4065 - val_ROC_auc: 0.8842 - val_pr_auc: 0.5685 - val_accuracy: 0.8562
# Epoch 1963/2000
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4169 - ROC_auc: 0.8779 - pr_auc: 0.5485 - accuracy: 0.8544 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1964/2000
# 1/1 [==============================] - 0s 328ms/step - loss: 0.4190 - ROC_auc: 0.8765 - pr_auc: 0.5462 - accuracy: 0.8539 - val_loss: 0.4056 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1965/2000
# 1/1 [==============================] - 0s 304ms/step - loss: 0.4190 - ROC_auc: 0.8766 - pr_auc: 0.5454 - accuracy: 0.8539 - val_loss: 0.4056 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1966/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.4204 - ROC_auc: 0.8764 - pr_auc: 0.5449 - accuracy: 0.8538 - val_loss: 0.4054 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1967/2000
# 1/1 [==============================] - 0s 319ms/step - loss: 0.4161 - ROC_auc: 0.8781 - pr_auc: 0.5476 - accuracy: 0.8547 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1968/2000
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4180 - ROC_auc: 0.8775 - pr_auc: 0.5479 - accuracy: 0.8541 - val_loss: 0.4060 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1969/2000
# 1/1 [==============================] - 0s 317ms/step - loss: 0.4163 - ROC_auc: 0.8784 - pr_auc: 0.5494 - accuracy: 0.8546 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1970/2000
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4184 - ROC_auc: 0.8768 - pr_auc: 0.5469 - accuracy: 0.8535 - val_loss: 0.4055 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1971/2000
# 1/1 [==============================] - 0s 316ms/step - loss: 0.4179 - ROC_auc: 0.8776 - pr_auc: 0.5489 - accuracy: 0.8544 - val_loss: 0.4057 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1972/2000
# 1/1 [==============================] - 0s 306ms/step - loss: 0.4191 - ROC_auc: 0.8773 - pr_auc: 0.5482 - accuracy: 0.8540 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1973/2000
# 1/1 [==============================] - 0s 317ms/step - loss: 0.4162 - ROC_auc: 0.8777 - pr_auc: 0.5493 - accuracy: 0.8544 - val_loss: 0.4058 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1974/2000
# 1/1 [==============================] - 0s 243ms/step - loss: 0.4211 - ROC_auc: 0.8765 - pr_auc: 0.5447 - accuracy: 0.8535 - val_loss: 0.4053 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1975/2000
# 1/1 [==============================] - 0s 244ms/step - loss: 0.4179 - ROC_auc: 0.8774 - pr_auc: 0.5473 - accuracy: 0.8537 - val_loss: 0.4056 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1976/2000
# 1/1 [==============================] - 0s 225ms/step - loss: 0.4176 - ROC_auc: 0.8774 - pr_auc: 0.5481 - accuracy: 0.8544 - val_loss: 0.4057 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5689 - val_accuracy: 0.8562
# Epoch 1977/2000
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4187 - ROC_auc: 0.8768 - pr_auc: 0.5461 - accuracy: 0.8538 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1978/2000
# 1/1 [==============================] - 0s 236ms/step - loss: 0.4183 - ROC_auc: 0.8769 - pr_auc: 0.5468 - accuracy: 0.8535 - val_loss: 0.4055 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1979/2000
# 1/1 [==============================] - 0s 229ms/step - loss: 0.4186 - ROC_auc: 0.8770 - pr_auc: 0.5461 - accuracy: 0.8542 - val_loss: 0.4055 - val_ROC_auc: 0.8847 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1980/2000
# 1/1 [==============================] - 0s 228ms/step - loss: 0.4198 - ROC_auc: 0.8766 - pr_auc: 0.5452 - accuracy: 0.8532 - val_loss: 0.4053 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1981/2000
# 1/1 [==============================] - 0s 239ms/step - loss: 0.4162 - ROC_auc: 0.8779 - pr_auc: 0.5490 - accuracy: 0.8549 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1982/2000
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4166 - ROC_auc: 0.8774 - pr_auc: 0.5486 - accuracy: 0.8541 - val_loss: 0.4061 - val_ROC_auc: 0.8844 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1983/2000
# 1/1 [==============================] - 0s 284ms/step - loss: 0.4186 - ROC_auc: 0.8776 - pr_auc: 0.5480 - accuracy: 0.8547 - val_loss: 0.4050 - val_ROC_auc: 0.8850 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1984/2000
# 1/1 [==============================] - 0s 227ms/step - loss: 0.4171 - ROC_auc: 0.8774 - pr_auc: 0.5473 - accuracy: 0.8542 - val_loss: 0.4053 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1985/2000
# 1/1 [==============================] - 0s 273ms/step - loss: 0.4177 - ROC_auc: 0.8779 - pr_auc: 0.5478 - accuracy: 0.8543 - val_loss: 0.4061 - val_ROC_auc: 0.8844 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1986/2000
# 1/1 [==============================] - 0s 292ms/step - loss: 0.4166 - ROC_auc: 0.8778 - pr_auc: 0.5485 - accuracy: 0.8546 - val_loss: 0.4050 - val_ROC_auc: 0.8851 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1987/2000
# 1/1 [==============================] - 0s 229ms/step - loss: 0.4179 - ROC_auc: 0.8768 - pr_auc: 0.5478 - accuracy: 0.8536 - val_loss: 0.4064 - val_ROC_auc: 0.8843 - val_pr_auc: 0.5687 - val_accuracy: 0.8562
# Epoch 1988/2000
# 1/1 [==============================] - 0s 288ms/step - loss: 0.4187 - ROC_auc: 0.8779 - pr_auc: 0.5483 - accuracy: 0.8544 - val_loss: 0.4050 - val_ROC_auc: 0.8850 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1989/2000
# 1/1 [==============================] - 0s 226ms/step - loss: 0.4182 - ROC_auc: 0.8776 - pr_auc: 0.5459 - accuracy: 0.8530 - val_loss: 0.4051 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1990/2000
# 1/1 [==============================] - 0s 230ms/step - loss: 0.4178 - ROC_auc: 0.8761 - pr_auc: 0.5459 - accuracy: 0.8542 - val_loss: 0.4061 - val_ROC_auc: 0.8845 - val_pr_auc: 0.5688 - val_accuracy: 0.8562
# Epoch 1991/2000
# 1/1 [==============================] - 0s 291ms/step - loss: 0.4193 - ROC_auc: 0.8763 - pr_auc: 0.5452 - accuracy: 0.8543 - val_loss: 0.4050 - val_ROC_auc: 0.8851 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1992/2000
# 1/1 [==============================] - 0s 232ms/step - loss: 0.4174 - ROC_auc: 0.8773 - pr_auc: 0.5473 - accuracy: 0.8539 - val_loss: 0.4057 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1993/2000
# 1/1 [==============================] - 0s 226ms/step - loss: 0.4174 - ROC_auc: 0.8771 - pr_auc: 0.5475 - accuracy: 0.8551 - val_loss: 0.4052 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1994/2000
# 1/1 [==============================] - 0s 235ms/step - loss: 0.4194 - ROC_auc: 0.8769 - pr_auc: 0.5465 - accuracy: 0.8542 - val_loss: 0.4051 - val_ROC_auc: 0.8850 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1995/2000
# 1/1 [==============================] - 0s 230ms/step - loss: 0.4161 - ROC_auc: 0.8781 - pr_auc: 0.5495 - accuracy: 0.8542 - val_loss: 0.4058 - val_ROC_auc: 0.8846 - val_pr_auc: 0.5690 - val_accuracy: 0.8562
# Epoch 1996/2000
# 1/1 [==============================] - 0s 228ms/step - loss: 0.4164 - ROC_auc: 0.8783 - pr_auc: 0.5501 - accuracy: 0.8549 - val_loss: 0.4051 - val_ROC_auc: 0.8850 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1997/2000
# 1/1 [==============================] - 0s 231ms/step - loss: 0.4179 - ROC_auc: 0.8769 - pr_auc: 0.5469 - accuracy: 0.8542 - val_loss: 0.4053 - val_ROC_auc: 0.8849 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 1998/2000
# 1/1 [==============================] - 0s 217ms/step - loss: 0.4190 - ROC_auc: 0.8773 - pr_auc: 0.5466 - accuracy: 0.8540 - val_loss: 0.4055 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5691 - val_accuracy: 0.8562
# Epoch 1999/2000
# 1/1 [==============================] - 0s 231ms/step - loss: 0.4165 - ROC_auc: 0.8783 - pr_auc: 0.5498 - accuracy: 0.8549 - val_loss: 0.4051 - val_ROC_auc: 0.8850 - val_pr_auc: 0.5692 - val_accuracy: 0.8562
# Epoch 2000/2000
# 1/1 [==============================] - 0s 278ms/step - loss: 0.4184 - ROC_auc: 0.8775 - pr_auc: 0.5474 - accuracy: 0.8542 - val_loss: 0.4053 - val_ROC_auc: 0.8848 - val_pr_auc: 0.5691 - val_accuracy: 0.8562

# %% [markdown]
# ### IV. Model Evaluation
#
# Accuracy and Loss in Model predictions

# %%
print("Evaluating model.")
loader_te = SingleLoader(dataset, sample_weights=weights_te)
eval_results = model.evaluate(loader_te.load(), steps=loader_te.steps_per_epoch)
print("Done.\n" "Test loss: {}\n" "Test accuracy: {}".format(*eval_results))
# Out:
# Evaluating model.
# 1/1 [==============================] - 0s 165ms/step - loss: 0.3987 - ROC_auc: 0.8848 - pr_auc: 0.5691 - accuracy: 0.8575
# Done.
# Test loss: 0.39874526858329773
# Test accuracy: 0.8848407864570618
